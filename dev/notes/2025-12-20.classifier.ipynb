# %%
from splatlog.lib.collections.classifier import Classifier

c: Classifier[int, str] = Classifier(
    {
        range(0, 5): "a",
        range(5, 10): "b",
    }
)

assert c[1] == "a"
assert c[5] == "b"
assert 12 not in c

# %%
list(c.items())
# Out:
# [(0, 'a'),
#  (1, 'a'),
#  (2, 'a'),
#  (3, 'a'),
#  (4, 'a'),
#  (5, 'b'),
#  (6, 'b'),
#  (7, 'b'),
#  (8, 'b'),
#  (9, 'b')]
